# %%
import json

# %%
filepath = "datasets/MoCoViolations_2018.json"

# %%
with open(filepath) as file: 
    violation_data = json.load(file)

# %%
type(violation_data)
# Out:
# dict

# %%
violation_data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
violation_data['meta'].keys()
# Out:
# dict_keys(['view'])

# %%
violation_data['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
violation_data['meta']['view']['columns']
# Out:
# [{'id': -1,
#   'name': 'sid',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':sid',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'id',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':id',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'position',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':position',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'created_at',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':created_at',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'created_meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':created_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'updated_at',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':updated_at',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'updated_meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':updated_meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'meta',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':meta',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': 402237369,
#   'name': 'SeqID',
#   'dataTypeName': 'text',
#   'description': 'Unique traffic stop ID',
#   'fieldName': 'seq_id',
#   'position': 2,
#   'renderTypeName': 'text',
#   'tableColumnId': 78891653,
#   'width': 100,
#   'cachedContents': {'largest': 'fffff914-df6f-4634-97d3-e2202f3d1f86',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': '33c49de3-9e36-4f36-9326-b59a95e86fe8', 'count': '59'},
#     {'item': '75f55258-401e-4a3d-87e6-ff9394acb877', 'count': '43'},
#     {'item': '28c5bfc1-5670-4751-be16-e1d83cda20f0', 'count': '42'},
#     {'item': 'c474e98e-128c-40e0-a487-d988cc67f0bd', 'count': '40'},
#     {'item': '859768f4-bde0-427b-a60f-07b1e2aaadc4', 'count': '40'},
#     {'item': '89d195ed-c995-4dda-b38f-cd784b782321', 'count': '38'},
#     {'item': '42ee969e-cc65-4557-bc1a-cefa6b35cba8', 'count': '38'},
#     {'item': '8fe624e5-2bef-4cf9-963b-58fbb1e206c2', 'count': '38'},
#     {'item': 'e8b8ff98-63f0-4e60-8fda-d1b8c69672da', 'count': '36'},
#     {'item': 'd8c32585-3c35-4862-987b-aa65d36a53db', 'count': '36'},
#     {'item': '1f0803c8-b026-4f42-a04b-a3c43404e26f', 'count': '34'},
#     {'item': '627dcae7-89cb-4f77-a9a8-2e70904bc104', 'count': '33'},
#     {'item': '5b92200b-57e1-4483-9e03-81af3fb39492', 'count': '33'},
#     {'item': '7d670eaa-2148-4f25-b236-f81a51501894', 'count': '33'},
#     {'item': 'e1fdbb16-88b3-409f-934d-a8ca6cc3f2b1', 'count': '33'},
#     {'item': 'd702af91-91a8-4402-be24-1bd73e43454e', 'count': '33'},
#     {'item': '5d1a83d7-ea71-47d8-82ae-b2b43fc5370d', 'count': '32'},
#     {'item': '7cafba7d-f098-4e6c-aaea-20a3a5cf6cb4', 'count': '32'},
#     {'item': '297d313b-c11d-452e-938e-bb1d478d9125', 'count': '31'},
#     {'item': '4667095b-656f-41e3-8a9b-45d77a1fd430', 'count': '31'}],
#    'smallest': '00001e27-8bde-4328-8b33-2d2d9a9ce862',
#    'not_null': '1507473',
#    'cardinality': '855050'},
#   'format': {}},
#  {'id': 402237334,
#   'name': 'Date Of Stop',
#   'dataTypeName': 'calendar_date',
#   'description': 'Date of the traffic violation.',
#   'fieldName': 'date_of_stop',
#   'position': 3,
#   'renderTypeName': 'calendar_date',
#   'tableColumnId': 20333361,
#   'width': 97,
#   'cachedContents': {'largest': '2019-04-24T00:00:00.000',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': '2015-03-17T00:00:00.000', 'count': '1281'},
#     {'item': '2018-04-10T00:00:00.000', 'count': '1277'},
#     {'item': '2014-05-20T00:00:00.000', 'count': '1222'},
#     {'item': '2019-03-05T00:00:00.000', 'count': '1186'},
#     {'item': '2018-04-18T00:00:00.000', 'count': '1185'},
#     {'item': '2015-11-24T00:00:00.000', 'count': '1169'},
#     {'item': '2017-01-25T00:00:00.000', 'count': '1167'},
#     {'item': '2015-12-08T00:00:00.000', 'count': '1150'},
#     {'item': '2016-03-08T00:00:00.000', 'count': '1141'},
#     {'item': '2015-02-11T00:00:00.000', 'count': '1135'},
#     {'item': '2014-05-06T00:00:00.000', 'count': '1128'},
#     {'item': '2016-03-07T00:00:00.000', 'count': '1127'},
#     {'item': '2017-02-21T00:00:00.000', 'count': '1110'},
#     {'item': '2015-10-20T00:00:00.000', 'count': '1101'},
#     {'item': '2016-03-09T00:00:00.000', 'count': '1099'},
#     {'item': '2015-01-20T00:00:00.000', 'count': '1098'},
#     {'item': '2019-03-12T00:00:00.000', 'count': '1089'},
#     {'item': '2019-04-09T00:00:00.000', 'count': '1087'},
#     {'item': '2014-05-14T00:00:00.000', 'count': '1087'},
#     {'item': '2018-02-21T00:00:00.000', 'count': '1087'}],
#    'smallest': '2012-01-01T00:00:00.000',
#    'not_null': '1507473',
#    'cardinality': '2670'},
#   'format': {'view': 'date', 'align': 'left'}},
#  {'id': 402237335,
#   'name': 'Time Of Stop',
#   'dataTypeName': 'text',
#   'description': 'Time of the traffic violation.',
#   'fieldName': 'time_of_stop',
#   'position': 4,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333363,
#   'width': 89,
#   'cachedContents': {'largest': '23:59:00',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': '23:30:00', 'count': '2293'},
#     {'item': '22:50:00', 'count': '2273'},
#     {'item': '22:53:00', 'count': '2266'},
#     {'item': '23:00:00', 'count': '2226'},
#     {'item': '23:20:00', 'count': '2221'},
#     {'item': '22:57:00', 'count': '2218'},
#     {'item': '22:29:00', 'count': '2210'},
#     {'item': '22:42:00', 'count': '2205'},
#     {'item': '23:12:00', 'count': '2173'},
#     {'item': '23:07:00', 'count': '2161'},
#     {'item': '22:31:00', 'count': '2155'},
#     {'item': '22:55:00', 'count': '2154'},
#     {'item': '22:44:00', 'count': '2151'},
#     {'item': '22:39:00', 'count': '2139'},
#     {'item': '22:47:00', 'count': '2138'},
#     {'item': '22:48:00', 'count': '2133'},
#     {'item': '22:46:00', 'count': '2117'},
#     {'item': '23:10:00', 'count': '2109'},
#     {'item': '23:15:00', 'count': '2107'},
#     {'item': '22:30:00', 'count': '2104'}],
#    'smallest': '00:00:00',
#    'not_null': '1507473',
#    'cardinality': '1440'},
#   'format': {'align': 'left'}},
#  {'id': 402237336,
#   'name': 'Agency',
#   'dataTypeName': 'text',
#   'description': 'Agency issuing the traffic violation.  (Example: MCP is Montgomery County Police)',
#   'fieldName': 'agency',
#   'position': 5,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333364,
#   'width': 63,
#   'cachedContents': {'largest': 'MCP',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'MCP', 'count': '1507473'}],
#    'smallest': 'MCP',
#    'not_null': '1507473',
#    'cardinality': '1'},
#   'format': {'align': 'left'}},
#  {'id': 402237337,
#   'name': 'SubAgency',
#   'dataTypeName': 'text',
#   'description': 'Court code representing the district of assignment of the officer. \nR15 = 1st district, Rockville\nB15 = 2nd district, Bethesda\nSS15 = 3rd district, Silver Spring\nWG15 = 4th district, Wheaton\nG15 = 5th district, Germantown\nM15 = 6th district, Gaithersburg / Montgomery Village\nHQ15 = Headquarters and Special Operations',
#   'fieldName': 'subagency',
#   'position': 6,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333366,
#   'width': 259,
#   'cachedContents': {'largest': 'W15',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': '4th District, Wheaton', 'count': '372203'},
#     {'item': '3rd District, Silver Spring', 'count': '295648'},
#     {'item': '2nd District, Bethesda', 'count': '242389'},
#     {'item': '6th District, Gaithersburg / Montgomery Village',
#      'count': '194237'},
#     {'item': '1st District, Rockville', 'count': '180707'},
#     {'item': '5th District, Germantown', 'count': '172326'},
#     {'item': 'Headquarters and Special Operations', 'count': '49953'},
#     {'item': 'W15', 'count': '7'},
#     {'item': 'S15', 'count': '3'}],
#    'smallest': '1st District, Rockville',
#    'not_null': '1507473',
#    'cardinality': '9'},
#   'format': {'align': 'left'}},
#  {'id': 402237338,
#   'name': 'Description',
#   'dataTypeName': 'text',
#   'description': 'Text description of the specific charge.',
#   'fieldName': 'description',
#   'position': 7,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333367,
#   'width': 720,
#   'cachedContents': {'largest': 'XX',
#    'non_null': 1500986,
#    'null': '8',
#    'top': [{'item': 'DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS',
#      'count': '123469'},
#     {'item': 'FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER',
#      'count': '70826'},
#     {'item': 'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#      'count': '48550'},
#     {'item': 'FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DISPLAY LICENSE TO UNIFORMED POLICE ON DEMAND',
#      'count': '39375'},
#     {'item': 'DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION',
#      'count': '36853'},
#     {'item': 'DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE',
#      'count': '35659'},
#     {'item': 'DRIVER FAILURE TO STOP AT STOP SIGN LINE', 'count': '34218'},
#     {'item': 'PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE',
#      'count': '29806'},
#     {'item': 'DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REGISTRATION PLATES AND VALIDATION TABS',
#      'count': '24768'},
#     {'item': 'EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH', 'count': '23945'},
#     {'item': 'EXCEEDING THE POSTED SPEED LIMIT OF 30 MPH', 'count': '23356'},
#     {'item': 'FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAMPS, ILLUMINATING DEVICE IN UNFAVORABLE VISIBILITY COND',
#      'count': '21161'},
#     {'item': 'STOP LIGHTS (*)', 'count': '20847'},
#     {'item': 'DRIVING MOTOR VEHICLE ON HIGHWAY WITHOUT REQUIRED LICENSE AND AUTHORIZATION',
#      'count': '20185'},
#     {'item': 'DRIVER CHANGING LANES WHEN UNSAFE', 'count': '20120'},
#     {'item': 'NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPRUDENT MANNER ENDANGERING PROPERTY, LIFE AND PERSON',
#      'count': '20094'},
#     {'item': 'EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH', 'count': '18688'},
#     {'item': 'DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF ALCOHOL',
#      'count': '18462'},
#     {'item': 'OPERATOR NOT RESTRAINED BY SEATBELT', 'count': '18344'},
#     {'item': 'DRIVING VEH. W/O ADEQUATE REAR REG. PLATE ILLUMINATION',
#      'count': '17115'}],
#    'smallest': ')',
#    'not_null': '1507465',
#    'cardinality': '13866'},
#   'format': {'align': 'left'}},
#  {'id': 402237339,
#   'name': 'Location',
#   'dataTypeName': 'text',
#   'description': 'Location of the violation, usually an address or intersection.',
#   'fieldName': 'location',
#   'position': 8,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333369,
#   'width': 302,
#   'cachedContents': {'largest': 'ZION ROAD @ RIGGS ROAD',
#    'non_null': 1500992,
#    'null': '2',
#    'top': [{'item': 'WAYNE AVE @ DALE DR', 'count': '2140'},
#     {'item': 'IS 370 @ IS 270', 'count': '1982'},
#     {'item': 'W/B IS 370 @ IS 270', 'count': '1884'},
#     {'item': 'MONTGOMERY VILLAGE AVE @ RUSSELL AVE', 'count': '1773'},
#     {'item': 'WOODFIELD RD @ EMORY GROVE RD', 'count': '1697'},
#     {'item': 'RT 28 @ BLACKBERRY DR', 'count': '1580'},
#     {'item': '10901 WESTLAKE DRIVE', 'count': '1504'},
#     {'item': 'RANDOLPH / COLIE', 'count': '1496'},
#     {'item': 'COLESVILLE RD @ GEORGIA AVE', 'count': '1450'},
#     {'item': 'CLOPPER RD E/B @ ORCHARD HILLS DR', 'count': '1323'},
#     {'item': 'RIDGE RD @ OBSERVATION DR', 'count': '1273'},
#     {'item': 'WAYNE AVE / DALE DR', 'count': '1256'},
#     {'item': 'FREDERICK RD/COLLEGE PKWY', 'count': '1234'},
#     {'item': 'GEORGIA AVE/COLESVILLE RD', 'count': '1076'},
#     {'item': 'GEORGIA AVE @ COLESVILLE RD', 'count': '1053'},
#     {'item': 'WB RT.198 @ SANTINI ROAD', 'count': '1033'},
#     {'item': 'CONNECTICUT AVE / DEAN RD', 'count': '978'},
#     {'item': 'GEORGIA AVE @ HEWITT AVE', 'count': '977'},
#     {'item': 'RIVER RD AND ROYAL DOMINION', 'count': '952'},
#     {'item': 'GEORGIA AVE @ CONNECTICUT AVE', 'count': '950'}],
#    'smallest': '011 RIDGE RD',
#    'not_null': '1507471',
#    'cardinality': '208229'},
#   'format': {'align': 'left'}},
#  {'id': 402237340,
#   'name': 'Latitude',
#   'dataTypeName': 'number',
#   'description': 'Latitude location of the traffic violation.',
#   'fieldName': 'latitude',
#   'position': 9,
#   'renderTypeName': 'number',
#   'tableColumnId': 20333562,
#   'width': 100,
#   'cachedContents': {'largest': '41.5431599333333',
#    'non_null': 1500994,
#    'average': '36.24774747966155',
#    'null': '0',
#    'top': [{'item': '0', 'count': '109169'},
#     {'item': '39.045425', 'count': '608'},
#     {'item': '39.0462766666667', 'count': '434'},
#     {'item': '39.109775', 'count': '330'},
#     {'item': '39.0056183333333', 'count': '268'},
#     {'item': '39.11061', 'count': '256'},
#     {'item': '39.057555', 'count': '245'},
#     {'item': '39.0584016666667', 'count': '161'},
#     {'item': '39.0039', 'count': '157'},
#     {'item': '39.0584133333333', 'count': '147'},
#     {'item': '39.058425', 'count': '146'},
#     {'item': '39.05844', 'count': '144'},
#     {'item': '39.0584066666667', 'count': '144'},
#     {'item': '39.0584333333333', 'count': '143'},
#     {'item': '39.0584083333333', 'count': '143'},
#     {'item': '39.0584', 'count': '141'},
#     {'item': '39.0583766666667', 'count': '141'},
#     {'item': '39.1492783333333', 'count': '140'},
#     {'item': '39.0584116666667', 'count': '140'},
#     {'item': '39.0584233333333', 'count': '137'}],
#    'smallest': '0',
#    'not_null': '1507473',
#    'sum': '54407651.480487103833933',
#    'cardinality': '297329'},
#   'format': {'precisionStyle': 'standard',
#    'noCommas': 'false',
#    'align': 'left'}},
#  {'id': 402237341,
#   'name': 'Longitude',
#   'dataTypeName': 'number',
#   'description': 'Longitude location of the traffic violation.',
#   'fieldName': 'longitude',
#   'position': 10,
#   'renderTypeName': 'number',
#   'tableColumnId': 20333563,
#   'width': 120,
#   'cachedContents': {'largest': '39.064435',
#    'non_null': 1500994,
#    'average': '-71.51955682237379',
#    'null': '0',
#    'top': [{'item': '0', 'count': '109169'},
#     {'item': '-76.9907366666667', 'count': '560'},
#     {'item': '-76.990695', 'count': '446'},
#     {'item': '-76.91044', 'count': '327'},
#     {'item': '-76.9897983333333', 'count': '272'},
#     {'item': '-77.0123283333333', 'count': '270'},
#     {'item': '-76.9678266666667', 'count': '214'},
#     {'item': '-77.0480666666667', 'count': '176'},
#     {'item': '-77.0480583333333', 'count': '161'},
#     {'item': '-77.036485', 'count': '157'},
#     {'item': '-77.048055', 'count': '148'},
#     {'item': '-77.0479833333333', 'count': '142'},
#     {'item': '-77.046385', 'count': '135'},
#     {'item': '-77.0271333333333', 'count': '135'},
#     {'item': '-77.06662', 'count': '134'},
#     {'item': '-77.0480683333333', 'count': '127'},
#     {'item': '-77.048375', 'count': '126'},
#     {'item': '-77.1609483333333', 'count': '125'},
#     {'item': '-77.0480916666667', 'count': '122'},
#     {'item': '-77.048035', 'count': '122'}],
#    'smallest': '-151.255986666667',
#    'not_null': '1507473',
#    'sum': '-107350425.6730421260899',
#    'cardinality': '337333'},
#   'format': {'precisionStyle': 'standard',
#    'noCommas': 'false',
#    'align': 'left'}},
#  {'id': 402237342,
#   'name': 'Accident',
#   'dataTypeName': 'text',
#   'description': 'YES if traffic violation involved an accident.',
#   'fieldName': 'accident',
#   'position': 11,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333390,
#   'width': 70,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1461085'},
#     {'item': 'Yes', 'count': '28795'},
#     {'item': '2', 'count': '11381'},
#     {'item': '3', 'count': '5211'},
#     {'item': '4', 'count': '670'},
#     {'item': '5', 'count': '331'}],
#    'smallest': '2',
#    'not_null': '1507473',
#    'cardinality': '6'},
#   'format': {'align': 'left'}},
#  {'id': 402237343,
#   'name': 'Belts',
#   'dataTypeName': 'text',
#   'description': 'YES if seat belts were in use in accident cases.',
#   'fieldName': 'belts',
#   'position': 12,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333391,
#   'width': 57,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1459303'},
#     {'item': 'Yes', 'count': '48170'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237344,
#   'name': 'Personal Injury',
#   'dataTypeName': 'text',
#   'description': 'Yes if traffic violation involved Personal Injury.',
#   'fieldName': 'personal_injury',
#   'position': 13,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333392,
#   'width': 86,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1490211'},
#     {'item': 'Yes', 'count': '17262'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237345,
#   'name': 'Property Damage',
#   'dataTypeName': 'text',
#   'description': 'Yes if traffic violation involved Property Damage.',
#   'fieldName': 'property_damage',
#   'position': 14,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333393,
#   'width': 98,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1478678'},
#     {'item': 'Yes', 'count': '28795'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237346,
#   'name': 'Fatal',
#   'dataTypeName': 'text',
#   'description': 'Yes if traffic violation involved a fatality.',
#   'fieldName': 'fatal',
#   'position': 15,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333394,
#   'width': 50,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1507142'},
#     {'item': 'Yes', 'count': '331'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237347,
#   'name': 'Commercial License',
#   'dataTypeName': 'text',
#   'description': 'Yes if driver holds a Commercial Drivers License',
#   'fieldName': 'commercial_license',
#   'position': 16,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333395,
#   'width': 118,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1463371'},
#     {'item': 'Yes', 'count': '44102'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237348,
#   'name': 'HAZMAT',
#   'dataTypeName': 'text',
#   'description': 'Yes if the traffic violation involved hazardous materials.',
#   'fieldName': 'hazmat',
#   'position': 17,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333396,
#   'width': 65,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1507341'},
#     {'item': 'Yes', 'count': '132'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237349,
#   'name': 'Commercial Vehicle',
#   'dataTypeName': 'text',
#   'description': 'Yes if the vehicle committing the traffic violation is a commercial vehicle.',
#   'fieldName': 'commercial_vehicle',
#   'position': 18,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333398,
#   'width': 117,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1500851'},
#     {'item': 'Yes', 'count': '6622'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237350,
#   'name': 'Alcohol',
#   'dataTypeName': 'text',
#   'description': 'Yes if the traffic violation included an alcohol related suspension.',
#   'fieldName': 'alcohol',
#   'position': 19,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333397,
#   'width': 54,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1505152'},
#     {'item': 'Yes', 'count': '2321'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237351,
#   'name': 'Work Zone',
#   'dataTypeName': 'text',
#   'description': 'Yes if the traffic violation was in a work zone.',
#   'fieldName': 'work_zone',
#   'position': 20,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333399,
#   'width': 69,
#   'cachedContents': {'largest': 'Yes',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'No', 'count': '1507172'},
#     {'item': 'Yes', 'count': '301'}],
#    'smallest': 'No',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237352,
#   'name': 'State',
#   'dataTypeName': 'text',
#   'description': 'State issuing the vehicle registration.',
#   'fieldName': 'state',
#   'position': 21,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333882,
#   'width': 50,
#   'cachedContents': {'largest': 'XX',
#    'non_null': 1500935,
#    'null': '59',
#    'top': [{'item': 'MD', 'count': '1315463'},
#     {'item': 'VA', 'count': '65257'},
#     {'item': 'DC', 'count': '38130'},
#     {'item': 'XX', 'count': '11998'},
#     {'item': 'PA', 'count': '10720'},
#     {'item': 'FL', 'count': '6896'},
#     {'item': 'TX', 'count': '6373'},
#     {'item': 'WV', 'count': '5994'},
#     {'item': 'NC', 'count': '5666'},
#     {'item': 'NY', 'count': '4944'},
#     {'item': 'NJ', 'count': '4233'},
#     {'item': 'GA', 'count': '3234'},
#     {'item': 'DE', 'count': '2871'},
#     {'item': 'CA', 'count': '2483'},
#     {'item': 'OH', 'count': '2370'},
#     {'item': 'MA', 'count': '1923'},
#     {'item': 'SC', 'count': '1633'},
#     {'item': 'IL', 'count': '1625'},
#     {'item': 'TN', 'count': '1412'},
#     {'item': 'MI', 'count': '1245'}],
#    'smallest': 'AB',
#    'not_null': '1507414',
#    'cardinality': '70'},
#   'format': {'align': 'left'}},
#  {'id': 402237353,
#   'name': 'VehicleType',
#   'dataTypeName': 'text',
#   'description': 'Type of vehicle (Examples: Automobile, Station Wagon, Heavy Duty Truck, etc.)',
#   'fieldName': 'vehicle_type',
#   'position': 22,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333370,
#   'width': 147,
#   'cachedContents': {'largest': '29 - Unknown',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': '02 - Automobile', 'count': '1327398'},
#     {'item': '05 - Light Duty Truck', 'count': '81179'},
#     {'item': '28 - Other', 'count': '27122'},
#     {'item': '03 - Station Wagon', 'count': '22865'},
#     {'item': '01 - Motorcycle', 'count': '13708'},
#     {'item': '06 - Heavy Duty Truck', 'count': '13247'},
#     {'item': '29 - Unknown', 'count': '9639'},
#     {'item': '08 - Recreational Vehicle', 'count': '4796'},
#     {'item': '25 - Utility Trailer', 'count': '1551'},
#     {'item': '19 - Moped', 'count': '1502'},
#     {'item': '07 - Truck/Road Tractor', 'count': '1418'},
#     {'item': '04 - Limousine', 'count': '861'},
#     {'item': '20 - Commercial Rig', 'count': '777'},
#     {'item': '10 - Transit Bus', 'count': '507'},
#     {'item': '12 - School Bus', 'count': '287'},
#     {'item': '27 - Farm Equipment', 'count': '127'},
#     {'item': '09 - Farm Vehicle', 'count': '106'},
#     {'item': '26 - Boat Trailer', 'count': '98'},
#     {'item': '21 - Tandem Trailer', 'count': '80'},
#     {'item': '11 - Cross Country Bus', 'count': '59'}],
#    'smallest': '01 - Motorcycle',
#    'not_null': '1507473',
#    'cardinality': '33'},
#   'format': {'align': 'left'}},
#  {'id': 402237354,
#   'name': 'Year',
#   'dataTypeName': 'text',
#   'description': 'Year vehicle was made.',
#   'fieldName': 'year',
#   'position': 23,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333372,
#   'width': 54,
#   'cachedContents': {'largest': '9999',
#    'non_null': 1491833,
#    'null': '9223',
#    'top': [{'item': '2006', 'count': '90585'},
#     {'item': '2007', 'count': '90294'},
#     {'item': '2005', 'count': '88710'},
#     {'item': '2004', 'count': '86430'},
#     {'item': '2003', 'count': '81816'},
#     {'item': '2008', 'count': '81139'},
#     {'item': '2012', 'count': '80706'},
#     {'item': '2013', 'count': '79169'},
#     {'item': '2011', 'count': '75975'},
#     {'item': '2002', 'count': '74385'},
#     {'item': '2010', 'count': '73000'},
#     {'item': '2014', 'count': '65967'},
#     {'item': '2001', 'count': '63550'},
#     {'item': '2000', 'count': '62977'},
#     {'item': '2009', 'count': '61606'},
#     {'item': '2015', 'count': '58970'},
#     {'item': '1999', 'count': '47504'},
#     {'item': '2016', 'count': '41880'},
#     {'item': '1998', 'count': '36940'},
#     {'item': '1997', 'count': '30216'}],
#    'smallest': '0',
#    'not_null': '1498250',
#    'cardinality': '340'},
#   'format': {'align': 'left'}},
#  {'id': 402237355,
#   'name': 'Make',
#   'dataTypeName': 'text',
#   'description': 'Manufacturer of the vehicle (Examples: Ford, Chevy, Honda, Toyota, etc.)',
#   'fieldName': 'make',
#   'position': 24,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333374,
#   'width': 88,
#   'cachedContents': {'largest': 'ZUZUKI',
#    'non_null': 1500993,
#    'null': '1',
#    'top': [{'item': 'TOYOTA', 'count': '172832'},
#     {'item': 'HONDA', 'count': '163132'},
#     {'item': 'FORD', 'count': '139925'},
#     {'item': 'TOYT', 'count': '84322'},
#     {'item': 'NISSAN', 'count': '80762'},
#     {'item': 'HOND', 'count': '56874'},
#     {'item': 'CHEV', 'count': '45177'},
#     {'item': 'BMW', 'count': '41437'},
#     {'item': 'DODGE', 'count': '40000'},
#     {'item': 'CHEVY', 'count': '34166'},
#     {'item': 'ACURA', 'count': '33862'},
#     {'item': 'JEEP', 'count': '33861'},
#     {'item': 'NISS', 'count': '32997'},
#     {'item': 'CHEVROLET', 'count': '32435'},
#     {'item': 'HYUNDAI', 'count': '29595'},
#     {'item': 'LEXUS', 'count': '24433'},
#     {'item': 'MERZ', 'count': '22206'},
#     {'item': 'MAZDA', 'count': '21723'},
#     {'item': 'KIA', 'count': '20286'},
#     {'item': 'GMC', 'count': '19892'}],
#    'smallest': '-',
#    'not_null': '1507472',
#    'cardinality': '3860'},
#   'format': {'align': 'left'}},
#  {'id': 402237356,
#   'name': 'Model',
#   'dataTypeName': 'text',
#   'description': 'Model of the vehicle.',
#   'fieldName': 'model',
#   'position': 25,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333376,
#   'width': 100,
#   'cachedContents': {'largest': 'ZZR1200',
#    'non_null': 1500959,
#    'null': '35',
#    'top': [{'item': '4S', 'count': '167270'},
#     {'item': 'TK', 'count': '97925'},
#     {'item': 'ACCORD', 'count': '55713'},
#     {'item': 'CIVIC', 'count': '52827'},
#     {'item': 'CAMRY', 'count': '51313'},
#     {'item': 'COROLLA', 'count': '45240'},
#     {'item': 'ALTIMA', 'count': '29245'},
#     {'item': '4D', 'count': '25228'},
#     {'item': '2S', 'count': '25172'},
#     {'item': 'SUV', 'count': '22229'},
#     {'item': '4DR', 'count': '20121'},
#     {'item': 'VN', 'count': '18646'},
#     {'item': 'VAN', 'count': '16389'},
#     {'item': 'CRV', 'count': '14429'},
#     {'item': 'SENTRA', 'count': '12671'},
#     {'item': 'RAV4', 'count': '12564'},
#     {'item': 'EXPLORER', 'count': '12415'},
#     {'item': 'SONATA', 'count': '12229'},
#     {'item': 'ODYSSEY', 'count': '10822'},
#     {'item': 'ELANTRA', 'count': '10756'}],
#    'smallest': '-',
#    'not_null': '1507438',
#    'cardinality': '19022'},
#   'format': {'align': 'left'}},
#  {'id': 402237357,
#   'name': 'Color',
#   'dataTypeName': 'text',
#   'description': 'Color of the vehicle.',
#   'fieldName': 'color',
#   'position': 26,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333379,
#   'width': 82,
#   'cachedContents': {'largest': 'YELLOW',
#    'non_null': 1499248,
#    'null': '1746',
#    'top': [{'item': 'BLACK', 'count': '306619'},
#     {'item': 'SILVER', 'count': '276101'},
#     {'item': 'WHITE', 'count': '234023'},
#     {'item': 'GRAY', 'count': '169295'},
#     {'item': 'RED', 'count': '117700'},
#     {'item': 'BLUE', 'count': '110065'},
#     {'item': 'GREEN', 'count': '54408'},
#     {'item': 'GOLD', 'count': '46541'},
#     {'item': 'BLUE, DARK', 'count': '31686'},
#     {'item': 'TAN', 'count': '30173'},
#     {'item': 'MAROON', 'count': '25540'},
#     {'item': 'BLUE, LIGHT', 'count': '19489'},
#     {'item': 'BEIGE', 'count': '16877'},
#     {'item': 'N/A', 'count': '16140'},
#     {'item': 'GREEN, DK', 'count': '15842'},
#     {'item': 'GREEN, LGT', 'count': '8355'},
#     {'item': 'BROWN', 'count': '6817'},
#     {'item': 'YELLOW', 'count': '5618'},
#     {'item': 'ORANGE', 'count': '5335'},
#     {'item': 'BRONZE', 'count': '3429'}],
#    'smallest': 'BEIGE',
#    'not_null': '1505727',
#    'cardinality': '27'},
#   'format': {'align': 'left'}},
#  {'id': 402237358,
#   'name': 'Violation Type',
#   'dataTypeName': 'text',
#   'description': 'Violation type.  (Examples: Warning, Citation, SERO)',
#   'fieldName': 'violation_type',
#   'position': 27,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333380,
#   'width': 96,
#   'cachedContents': {'largest': 'Warning',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'Warning', 'count': '747379'},
#     {'item': 'Citation', 'count': '685792'},
#     {'item': 'ESERO', 'count': '73403'},
#     {'item': 'SERO', 'count': '899'}],
#    'smallest': 'Citation',
#    'not_null': '1507473',
#    'cardinality': '4'},
#   'format': {'align': 'left'}},
#  {'id': 402237359,
#   'name': 'Charge',
#   'dataTypeName': 'text',
#   'description': 'Numeric code for the specific charge. ',
#   'fieldName': 'charge',
#   'position': 28,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333381,
#   'width': 90,
#   'cachedContents': {'largest': '9-337(a)',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': '21-801.1', 'count': '188736'},
#     {'item': '21-201(a1)', 'count': '123469'},
#     {'item': '13-409(b)', 'count': '71212'},
#     {'item': '13-401(h)', 'count': '49170'},
#     {'item': '21-707(a)', 'count': '49083'},
#     {'item': '16-112(c)', 'count': '39607'},
#     {'item': '21-1124.2(d2)', 'count': '37288'},
#     {'item': '13-411(f)', 'count': '36589'},
#     {'item': '16-101(a)', 'count': '31155'},
#     {'item': '16-303(c)', 'count': '30675'},
#     {'item': '16-303(h)', 'count': '30551'},
#     {'item': '64*', 'count': '28747'},
#     {'item': '22-412.3(b)', 'count': '27382'},
#     {'item': '21-801(a)', 'count': '26550'},
#     {'item': '13-411(d)', 'count': '25125'},
#     {'item': '21-309(b)', 'count': '21543'},
#     {'item': '22-201.1', 'count': '21294'},
#     {'item': '21-901.1(b)', 'count': '20341'},
#     {'item': '13-411(a)', 'count': '18957'},
#     {'item': '21-202(h1)', 'count': '18049'}],
#    'smallest': '10-303(a)',
#    'not_null': '1507473',
#    'cardinality': '1072'},
#   'format': {'align': 'left'}},
#  {'id': 402237360,
#   'name': 'Article',
#   'dataTypeName': 'text',
#   'description': 'Article of State Law.  (TA = Transportation Article, MR = Maryland Rules)',
#   'fieldName': 'article',
#   'position': 29,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333382,
#   'width': 133,
#   'cachedContents': {'largest': 'Transportation Article',
#    'non_null': 1426933,
#    'null': '74302',
#    'top': [{'item': 'Transportation Article', 'count': '1418605'},
#     {'item': 'Maryland Rules', 'count': '14510'},
#     {'item': 'BR', 'count': '37'},
#     {'item': 'TG', 'count': '19'}],
#    'smallest': 'BR',
#    'not_null': '1433171',
#    'cardinality': '4'},
#   'format': {'align': 'left'}},
#  {'id': 402237361,
#   'name': 'Contributed To Accident',
#   'dataTypeName': 'text',
#   'description': 'If the traffic violation was a contributing factor in an accident.',
#   'fieldName': 'contributed_to_accident',
#   'position': 30,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333389,
#   'width': 136,
#   'cachedContents': {'largest': 'true',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'false', 'count': '1471521'},
#     {'item': 'true', 'count': '35952'}],
#    'smallest': 'false',
#    'not_null': '1507473',
#    'cardinality': '2'},
#   'format': {'align': 'left'}},
#  {'id': 402237362,
#   'name': 'Race',
#   'dataTypeName': 'text',
#   'description': 'Race of the driver.  (Example: Asian, Black, White, Other, etc.)',
#   'fieldName': 'race',
#   'position': 31,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333383,
#   'width': 97,
#   'cachedContents': {'largest': 'WHITE',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'WHITE', 'count': '534635'},
#     {'item': 'BLACK', 'count': '477364'},
#     {'item': 'HISPANIC', 'count': '321869'},
#     {'item': 'ASIAN', 'count': '88414'},
#     {'item': 'OTHER', 'count': '82037'},
#     {'item': 'NATIVE AMERICAN', 'count': '3154'}],
#    'smallest': 'ASIAN',
#    'not_null': '1507473',
#    'cardinality': '6'},
#   'format': {'align': 'left'}},
#  {'id': 402237363,
#   'name': 'Gender',
#   'dataTypeName': 'text',
#   'description': 'Gender of the driver (F = Female, M = Male)',
#   'fieldName': 'gender',
#   'position': 32,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333384,
#   'width': 50,
#   'cachedContents': {'largest': 'U',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'M', 'count': '1009981'},
#     {'item': 'F', 'count': '495615'},
#     {'item': 'U', 'count': '1877'}],
#    'smallest': 'F',
#    'not_null': '1507473',
#    'cardinality': '3'},
#   'format': {'align': 'left'}},
#  {'id': 402237364,
#   'name': 'Driver City',
#   'dataTypeName': 'text',
#   'description': 'City of the driverâ€™s home address.',
#   'fieldName': 'driver_city',
#   'position': 33,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333385,
#   'width': 232,
#   'cachedContents': {'largest': 'ZSILVER SPRING',
#    'non_null': 1500887,
#    'null': '107',
#    'top': [{'item': 'SILVER SPRING', 'count': '375343'},
#     {'item': 'GAITHERSBURG', 'count': '155015'},
#     {'item': 'ROCKVILLE', 'count': '124293'},
#     {'item': 'GERMANTOWN', 'count': '123342'},
#     {'item': 'WASHINGTON', 'count': '46835'},
#     {'item': 'BETHESDA', 'count': '41618'},
#     {'item': 'MONTGOMERY VILLAGE', 'count': '40573'},
#     {'item': 'HYATTSVILLE', 'count': '34566'},
#     {'item': 'POTOMAC', 'count': '30404'},
#     {'item': 'OLNEY', 'count': '25823'},
#     {'item': 'LAUREL', 'count': '21154'},
#     {'item': 'FREDERICK', 'count': '20454'},
#     {'item': 'CLARKSBURG', 'count': '19345'},
#     {'item': 'TAKOMA PARK', 'count': '16162'},
#     {'item': 'KENSINGTON', 'count': '16064'},
#     {'item': 'NORTH POTOMAC', 'count': '16058'},
#     {'item': 'DAMASCUS', 'count': '14673'},
#     {'item': 'BURTONSVILLE', 'count': '13955'},
#     {'item': 'BELTSVILLE', 'count': '13309'},
#     {'item': 'CHEVY CHASE', 'count': '12281'}],
#    'smallest': '-',
#    'not_null': '1507366',
#    'cardinality': '7870'},
#   'format': {'align': 'left'}},
#  {'id': 402237365,
#   'name': 'Driver State',
#   'dataTypeName': 'text',
#   'description': 'State of the driverâ€™s home address.',
#   'fieldName': 'driver_state',
#   'position': 34,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333386,
#   'width': 66,
#   'cachedContents': {'largest': 'XX',
#    'non_null': 1500983,
#    'null': '11',
#    'top': [{'item': 'MD', 'count': '1360547'},
#     {'item': 'DC', 'count': '48622'},
#     {'item': 'VA', 'count': '47295'},
#     {'item': 'PA', 'count': '7776'},
#     {'item': 'FL', 'count': '5322'},
#     {'item': 'NY', 'count': '4606'},
#     {'item': 'NC', 'count': '3641'},
#     {'item': 'WV', 'count': '3282'},
#     {'item': 'CA', 'count': '2897'},
#     {'item': 'NJ', 'count': '2392'},
#     {'item': 'TX', 'count': '2199'},
#     {'item': 'GA', 'count': '2115'},
#     {'item': 'MA', 'count': '1554'},
#     {'item': 'DE', 'count': '1374'},
#     {'item': 'OH', 'count': '1337'},
#     {'item': 'IL', 'count': '1021'},
#     {'item': 'SC', 'count': '961'},
#     {'item': 'XX', 'count': '944'},
#     {'item': 'CT', 'count': '760'},
#     {'item': 'MI', 'count': '755'}],
#    'smallest': 'AB',
#    'not_null': '1507462',
#    'cardinality': '68'},
#   'format': {'align': 'left'}},
#  {'id': 402237366,
#   'name': 'DL State',
#   'dataTypeName': 'text',
#   'description': 'State issuing the Driverâ€™s License.',
#   'fieldName': 'dl_state',
#   'position': 35,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333387,
#   'width': 50,
#   'cachedContents': {'largest': 'XX',
#    'non_null': 1500065,
#    'null': '929',
#    'top': [{'item': 'MD', 'count': '1310883'},
#     {'item': 'VA', 'count': '50618'},
#     {'item': 'DC', 'count': '49399'},
#     {'item': 'XX', 'count': '20526'},
#     {'item': 'PA', 'count': '9310'},
#     {'item': 'FL', 'count': '8591'},
#     {'item': 'NY', 'count': '6685'},
#     {'item': 'NC', 'count': '5258'},
#     {'item': 'CA', 'count': '5102'},
#     {'item': 'TX', 'count': '3898'},
#     {'item': 'GA', 'count': '3459'},
#     {'item': 'WV', 'count': '3420'},
#     {'item': 'NJ', 'count': '3272'},
#     {'item': 'MA', 'count': '2480'},
#     {'item': 'OH', 'count': '1949'},
#     {'item': 'IL', 'count': '1708'},
#     {'item': 'DE', 'count': '1667'},
#     {'item': 'SC', 'count': '1569'},
#     {'item': 'WA', 'count': '1231'},
#     {'item': 'MI', 'count': '1198'}],
#    'smallest': 'AB',
#    'not_null': '1506544',
#    'cardinality': '70'},
#   'format': {'align': 'left'}},
#  {'id': 402237367,
#   'name': 'Arrest Type',
#   'dataTypeName': 'text',
#   'description': 'Type of Arrest (A = Marked, B = Unmarked, etc.)',
#   'fieldName': 'arrest_type',
#   'position': 36,
#   'renderTypeName': 'text',
#   'tableColumnId': 20333388,
#   'width': 208,
#   'cachedContents': {'largest': 'S - License Plate Recognition',
#    'non_null': 1500994,
#    'null': '0',
#    'top': [{'item': 'A - Marked Patrol', 'count': '1248946'},
#     {'item': 'Q - Marked Laser', 'count': '137713'},
#     {'item': 'B - Unmarked Patrol', 'count': '47602'},
#     {'item': 'S - License Plate Recognition', 'count': '14404'},
#     {'item': 'O - Foot Patrol', 'count': '13988'},
#     {'item': 'L - Motorcycle', 'count': '12746'},
#     {'item': 'E - Marked Stationary Radar', 'count': '9328'},
#     {'item': 'G - Marked Moving Radar (Stationary)', 'count': '8045'},
#     {'item': 'R - Unmarked Laser', 'count': '6105'},
#     {'item': 'I - Marked Moving Radar (Moving)', 'count': '2422'},
#     {'item': 'M - Marked (Off-Duty)', 'count': '2256'},
#     {'item': 'H - Unmarked Moving Radar (Stationary)', 'count': '1060'},
#     {'item': 'F - Unmarked Stationary Radar', 'count': '836'},
#     {'item': 'J - Unmarked Moving Radar (Moving)', 'count': '631'},
#     {'item': 'C - Marked VASCAR', 'count': '482'},
#     {'item': 'P - Mounted Patrol', 'count': '338'},
#     {'item': 'D - Unmarked VASCAR', 'count': '300'},
#     {'item': 'N - Unmarked (Off-Duty)', 'count': '216'},
#     {'item': 'K - Aircraft Assist', 'count': '55'}],
#    'smallest': 'A - Marked Patrol',
#    'not_null': '1507473',
#    'cardinality': '19'},
#   'format': {'align': 'left'}},
#  {'id': 402237368,
#   'name': 'Geolocation',
#   'dataTypeName': 'location',
#   'description': 'Geo-coded location information.',
#   'fieldName': 'geolocation',
#   'position': 37,
#   'renderTypeName': 'location',
#   'tableColumnId': 22014969,
#   'width': 100,
#   'format': {'view': 'address_coords', 'align': 'left'},
#   'subColumnTypes': ['human_address',
#    'latitude',
#    'longitude',
#    'machine_address',
#    'needs_recoding']},
#  {'id': 402240720,
#   'name': 'Council Districts',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_vu5j_pcmz',
#   'position': 44,
#   'renderTypeName': 'number',
#   'tableColumnId': 78893940,
#   'computationStrategy': {'source_columns': ['geolocation'],
#    'type': 'georegion_match_on_point',
#    'parameters': {'region': '_vu5j-pcmz', 'primary_key': '_feature_id'}},
#   'format': {}},
#  {'id': 402240721,
#   'name': 'Councils',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_tx5f_5em3',
#   'position': 45,
#   'renderTypeName': 'number',
#   'tableColumnId': 78893941,
#   'computationStrategy': {'source_columns': ['geolocation'],
#    'type': 'georegion_match_on_point',
#    'parameters': {'region': '_tx5f-5em3', 'primary_key': '_feature_id'}},
#   'format': {}},
#  {'id': 402240722,
#   'name': 'Communities',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_kbsp_ykn9',
#   'position': 46,
#   'renderTypeName': 'number',
#   'tableColumnId': 78893942,
#   'computationStrategy': {'source_columns': ['geolocation'],
#    'type': 'georegion_match_on_point',
#    'parameters': {'region': '_kbsp-ykn9', 'primary_key': '_feature_id'}},
#   'format': {}},
#  {'id': 402240723,
#   'name': 'Zip Codes',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_d7bw_bq6x',
#   'position': 47,
#   'renderTypeName': 'number',
#   'tableColumnId': 78893943,
#   'computationStrategy': {'source_columns': ['geolocation'],
#    'type': 'georegion_match_on_point',
#    'parameters': {'region': '_d7bw-bq6x', 'primary_key': '_feature_id'}},
#   'format': {}},
#  {'id': 402240724,
#   'name': 'Municipalities',
#   'dataTypeName': 'number',
#   'fieldName': ':@computed_region_rbt8_3x7n',
#   'position': 48,
#   'renderTypeName': 'number',
#   'tableColumnId': 78893944,
#   'computationStrategy': {'source_columns': ['geolocation'],
#    'type': 'georegion_match_on_point',
#    'parameters': {'region': '_rbt8-3x7n', 'primary_key': '_feature_id'}},
#   'format': {}}]

# %%
len(violation_data['data'])
# Out:
# 218273

# %%
violation_data['data'][0]
# Out:
# ['row-tb2z_it96-ased',
#  '00000000-0000-0000-D6FB-B97187EB8E43',
#  0,
#  1554316021,
#  None,
#  1554317159,
#  None,
#  '{ }',
#  'dcf9f7e6-9001-4ac9-b657-94a3cd8b29b8',
#  '2018-12-31T00:00:00',
#  '23:56:00',
#  'MCP',
#  '1st District, Rockville',
#  'FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAMPS, ILLUMINATING DEVICE IN UNFAVORABLE VISIBILITY COND',
#  '355 @ FIRST ST',
#  '39.07792',
#  '-77.1404116666667',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'MD',
#  '02 - Automobile',
#  '2007',
#  'TOYOTA',
#  'COROLLA',
#  'BLUE',
#  'Warning',
#  '22-201.1',
#  'Transportation Article',
#  'false',
#  'BLACK',
#  'M',
#  'GERMANTOWN',
#  'MD',
#  'MD',
#  'A - Marked Patrol',
#  [None, '39.07792', '-77.140411666667', None, False, None],
#  '3',
#  '3',
#  '25',
#  '60',
#  '12']

# %%
date_of_stop = []
time_of_stop = []
agency = []
subagency = []
description = []
location = []
latitude = []
longitude = []
vehicle_type = []
vehicle_year = []
vehicle_make = []
vehicle_model = []
vehicle_color = []
violation_type = []
race = []
gender = []
driver_state = []
driver_license_state = []
arrest_type = []

# %% [markdown]
# Time of Stop [10]
# Agency [11]
# Subagency [12]
# Description [13]
# Location [14]
# Latitude [15]
# Longitude [16]
# Vehicle Type [28]
# Vehicle Year [29]
# Vehicle Make [30]
# Vehicle Model [31]
# Vehicle Color [32]
# Violation Type [33]
# Race [37]
# Gender [38]
# Driver's State [40]
# Driver's License State [41]
# Arrest Type [42]

# %%
for item in violation_data['data']: 
    date_of_stop.append(item[9])
    time_of_stop.append(item[10])
    agency.append(item[11])
    subagency.append(item[12])
    description.append(item[13])
    location.append(item[14])
    longitude.append(item[16])
    latitude.append(item[15])
    vehicle_type.append(item[28])
    vehicle_year.append(item[29])
    vehicle_make.append(item[30])
    vehicle_model.append(item[31])
    vehicle_color.append(item[32])
    violation_type.append(item[33])
    race.append(item[37])
    gender.append(item[38])
    driver_state.append(item[40])
    driver_license_state.append(item[41])
    arrest_type.append(item[42])

# %%
len(driver_state)
# Out:
# 218273

# %% [raw]
# lists = [date_of_stop,
# time_of_stop,
# agency,
# subagency,
# description,
# location,
# latitude,
# longitude,
# vehicle_type,
# vehicle_year,
# vehicle_make,
# vehicle_model,
# vehicle_color,
# violation_type,
# race,
# gender,
# driver_state,
# driver_license_state,
# arrest_type]

# %%
all_lists = list(zip(date_of_stop,
time_of_stop,
agency,
subagency,
description,
location,
latitude,
longitude,
vehicle_type,
vehicle_year,
vehicle_make,
vehicle_model,
vehicle_color,
violation_type,
race,
gender,
driver_state,
driver_license_state,
arrest_type))

# %%
len(all_lists)
# Out:
# 218273

# %%
names = ['date_of_stop',
'time_of_stop',
'agency',
'subagency',
'description',
'location',
'latitude',
'longitude',
'vehicle_type',
'vehicle_year',
'vehicle_make',
'vehicle_model',
'vehicle_color',
'violation_type',
'race',
'gender',
'driver_state',
'driver_license_state',
'arrest_type']

# %%
import pandas as pd 
df = pd.DataFrame(all_lists, columns = names)

df.head()
# Out:
#           date_of_stop time_of_stop agency  \
# 0  2018-12-31T00:00:00     23:56:00    MCP
# 1  2018-12-31T00:00:00     23:52:00    MCP
# 2  2018-12-31T00:00:00     23:52:00    MCP
# 3  2018-12-31T00:00:00     23:45:00    MCP
# 4  2018-12-31T00:00:00     23:44:00    MCP
#
#                                          subagency  \
# 0                          1st District, Rockville
# 1  6th District, Gaithersburg / Montgomery Village
# 2  6th District, Gaithersburg / Montgomery Village
# 3                          1st District, Rockville
# 4              Headquarters and Special Operations
#
#                                          description  \
# 0  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 1  FAILURE TO DISPLAY TWO LIGHTED FRONT LAMPS WHE...
# 2  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 3  FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 4  FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROAD...
#
#                          location          latitude          longitude  \
# 0                  355 @ FIRST ST          39.07792  -77.1404116666667
# 1  N FREDERICK AVE @ ODENDHAL AVE  39.1486766666667  -77.2063433333333
# 2  N FREDERICK AVE @ ODENDHAL AVE  39.1486766666667  -77.2063433333333
# 3                      355 @ BEAL          39.08545  -77.1451033333333
# 4       FENTON ST @ COLESVILLE RD         38.997515  -77.0267766666667
#
#       vehicle_type vehicle_year vehicle_make vehicle_model vehicle_color  \
# 0  02 - Automobile         2007       TOYOTA       COROLLA          BLUE
# 1  02 - Automobile         2006        LEXUS            4S          GRAY
# 2  02 - Automobile         2006        LEXUS            4S          GRAY
# 3  02 - Automobile         2017       TOYOTA       COROLLA          GRAY
# 4  02 - Automobile         2016    CHEVROLET        IMPALA         BLACK
#
#   violation_type      race gender driver_state driver_license_state  \
# 0        Warning     BLACK      M           MD                   MD
# 1        Warning  HISPANIC      M           MD                   MD
# 2        Warning  HISPANIC      M           MD                   MD
# 3        Warning     WHITE      F           MD                   MD
# 4        Warning     BLACK      M           VA                   VA
#
#          arrest_type
# 0  A - Marked Patrol
# 1  A - Marked Patrol
# 2  A - Marked Patrol
# 3  A - Marked Patrol
# 4  A - Marked Patrol
